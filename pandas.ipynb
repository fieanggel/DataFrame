# %%
import pandas as pd

data = pd.read_excel('disperkim-od_16985_jumlah_produksi_sampah_berdasarkan_kabupatenkota_v3_data.xlsx', sheet_name='data')
data
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3202
# 2      3             32    JAWA BARAT                 3203
# 3      4             32    JAWA BARAT                 3204
# 4      5             32    JAWA BARAT                 3205
# ..   ...            ...           ...                  ...
# 238  239             32    JAWA BARAT                 3275
# 239  240             32    JAWA BARAT                 3276
# 240  241             32    JAWA BARAT                 3277
# 241  242             32    JAWA BARAT                 3278
# 242  243             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota  jumlah_produksi_sampah        satuan  tahun
# 0       KABUPATEN BOGOR                 1511.15  TON PER HARI   2015
# 1    KABUPATEN SUKABUMI                  419.01  TON PER HARI   2015
# ...

# %%
sampahtotal = 0
tahun = 2019
for index, row in data.iterrows():
    if row['tahun']== tahun:
        sampahtotal += row ['jumlah_produksi_sampah']
print(f"Total sampah tahun 2019: {sampahtotal} Ton")
# Out:
# Total sampah tahun 2019: 24490.559999999998 Ton

# %%
data = pd.DataFrame([{'Tahun': tahun, 'Total sampah (Ton)': sampahtotal}])
data
# data.to_csv('no2.csv', index=False)
# data.to_excel('no2.xlsx', index=False)
# Out:
#    Tahun  Total sampah (Ton)
# 0   2019            24490.56

# %%
smph_per_tahun = {}

for index, row in data.iterrows():
    tahun = row['tahun']
    jumlah = row['jumlah_produksi_sampah']
    if tahun in smph_per_tahun:
        smph_per_tahun[tahun] += jumlah
    else:
        smph_per_tahun[tahun] = jumlah

data = pd.DataFrame(smph_per_tahun.items(), columns=['Tahun', 'Total Produksi Sampah'])
data
# data.to_csv('no3.csv', index=False)
# data.to_excel('no3.xlsx', index=False)
# Out:
# Index: 0, Tahun: 2015, Jumlah: 1511.15
# Index: 1, Tahun: 2015, Jumlah: 419.01
# Index: 2, Tahun: 2015, Jumlah: 981.41
# Index: 3, Tahun: 2015, Jumlah: 1895.94
# Index: 4, Tahun: 2015, Jumlah: 464.74
# Index: 5, Tahun: 2015, Jumlah: 464.52
# Index: 6, Tahun: 2015, Jumlah: 260.91
# Index: 7, Tahun: 2015, Jumlah: 251.7
# Index: 8, Tahun: 2015, Jumlah: 465.75
# Index: 9, Tahun: 2015, Jumlah: 254.63
# Index: 10, Tahun: 2015, Jumlah: 237.96
# Index: 11, Tahun: 2015, Jumlah: 613.18
# Index: 12, Tahun: 2015, Jumlah: 487.26
# Index: 13, Tahun: 2015, Jumlah: 308.96
# Index: 14, Tahun: 2015, Jumlah: 869.86
# Index: 15, Tahun: 2015, Jumlah: 1228.6
# Index: 16, Tahun: 2015, Jumlah: 616.08
# Index: 17, Tahun: 2015, Jumlah: 185.83
# Index: 18, Tahun: 2015, Jumlah: 991.93
# Index: 19, Tahun: 2015, Jumlah: 309.91
# Index: 20, Tahun: 2015, Jumlah: 2448.63
# Index: 21, Tahun: 2015, Jumlah: 304.15
# Index: 22, Tahun: 2015, Jumlah: 2387.08
# Index: 23, Tahun: 2015, Jumlah: 1844.3
# ...

# %%
# data = pd.DataFrame(smph_per_tahun.items(), columns=['Tahun', 'Total Produksi Sampah'])
# data.to_csv('no3.csv', index=False)
# data.to_excel('no3.xlsx', index=False)

# %%
jml_data_perkota = {}

for index, row in data.iterrows():
    kota = row['nama_kabupaten_kota']
    tahun = row['tahun']
    jumlah = row['jumlah_produksi_sampah']
    
    if kota not in jml_data_perkota:
        jml_data_perkota[kota] = {}
    
    if tahun not in jml_data_perkota[kota]:
        jml_data_perkota[kota][tahun] = 0
    
    jml_data_perkota[kota][tahun] += jumlah

data = pd.DataFrame([
    {'Kabupaten/Kota': kota, 'Tahun': tahun, 'Jumlah Data': jumlah}
    for kota, data_tahun in jml_data_perkota.items()
    for tahun, jumlah in data_tahun.items()
])
data
data.to_csv('No4.csv', index=False)
data.to_excel('No4.xlsx', index=False)
# Out:
# id                                      1
# kode_provinsi                          32
# nama_provinsi                  JAWA BARAT
# kode_kabupaten_kota                  3201
# nama_kabupaten_kota       KABUPATEN BOGOR
# jumlah_produksi_sampah            1511.15
# satuan                       TON PER HARI
# tahun                                2015
# Name: 0, dtype: object
# id                                         2
# kode_provinsi                             32
# nama_provinsi                     JAWA BARAT
# kode_kabupaten_kota                     3202
# nama_kabupaten_kota       KABUPATEN SUKABUMI
# jumlah_produksi_sampah                419.01
# satuan                          TON PER HARI
# tahun                                   2015
# Name: 1, dtype: object
# id                                        3
# kode_provinsi                            32
# nama_provinsi                    JAWA BARAT
# kode_kabupaten_kota                    3203
# ...

# %%
# data = pd.DataFrame([
#     {'Kabupaten/Kota': kota, 'Tahun': tahun, 'Jumlah Data': jumlah}
#     for kota, data_tahun in jml_data_perkota.items()
#     for tahun, jumlah in data_tahun.items()
# ])

# data.to_csv('No4.csv', index=False)
# data.to_excel('No4.xlsx', index=False)
